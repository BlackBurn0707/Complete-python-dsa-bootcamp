# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def merge_three_dictionaries(dict1, dict2, dict3):
    dict1 = dict1 | dict2
    dict1 = dict1 | dict3
    return dict1

merge_three_dictionaries({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
def merge_three_dictionaries(dict1, dict2, dict3):
    # Create a new dictionary that starts with the content of dict1
    merged_dict = dict1.copy()
    
    # Add the key-value pairs from dict2
    for key, value in dict2.items():
        merged_dict[key] = value
    
    # Add the key-value pairs from dict3
    for key, value in dict3.items():
        merged_dict[key] = value
    
    return merged_dict
    
# Connect with me:
# YouTube: https://www.youtube.com/@tech.mayankagg
# Instagram: https://www.instagram.com/tech.mayankagg/
# LinkedIn: https://www.linkedin.com/in/mayank953/
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 8
#       5         dict1[key] = dict3[key]
#       6     return dict1
# ----> 8 merge_three_dictionaries({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})
#
# Cell In[4], line 3, in merge_three_dictionaries(dict1, dict2, dict3)
#       1 def merge_three_dictionaries(dict1, dict2, dict3):
#       2     for key, vaue in enumerate(dict2):
# ----> 3         dict1[key] = dict2[key]
#       4     for key, vaue in enumerate(dict3):
#       5         dict1[key] = dict3[key]
#
# KeyError: 0
