# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_even_odd(lst):
    even = 0
    odd = 0
    for item in lst:
        if item % 2 == 0:
            even += 1
        else:
            odd += 1
    return (even, odd)
