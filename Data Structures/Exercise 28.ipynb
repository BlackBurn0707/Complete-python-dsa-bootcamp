# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def merge_two_sorted_lists(list1, list2):
    merged_lst = list1 + list2
    for i in range(0, len(merged_lst), 1):
        for j in range(i, len(merged_lst), 1):
            if merged_lst[j] < merged_lst[i]:
                element = merged_lst[j]
                merged_lst.remove(merged_lst[j])
                merged_lst.insert(i, element)
    return merged_lst


merge_two_sorted_lists([1, 3, 5], [2, 4, 6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def merge_two_sorted_lists(list1, list2):
    # Initialize pointers for both lists
    i, j = 0, 0
    result = []  # Initialize an empty list to store the merged result
    
    # Traverse both lists and merge them in sorted order
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            result.append(list1[i])  # Add the smaller element to the result list
            i += 1
        else:
            result.append(list2[j])  # Add the smaller element to the result list
            j += 1
    
    # If there are remaining elements in list1, add them to the result
    while i < len(list1):
        result.append(list1[i])
        i += 1
    
    # If there are remaining elements in list2, add them to the result
    while j < len(list2):
        result.append(list2[j])
        j += 1
    
    return result  # Return the merged sorted list
    
# Connect with me:
# YouTube: https://www.youtube.com/@tech.mayankagg
# Instagram: https://www.instagram.com/tech.mayankagg/
# LinkedIn: https://www.linkedin.com/in/mayank953/
