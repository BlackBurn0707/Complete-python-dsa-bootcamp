# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def remove_duplicates(s):
    new_s = ''
    for letter in s:
        if letter not in new_s:
            new_s += letter
    return new_s

remove_duplicates('Hello, World!')
# Out:
# 'Helo, Wrd!'

# %%
def remove_duplicates(s):
    """
    Function to remove duplicate characters from the input string without using built-in functions.
    
    Parameters:
    s (str): The input string from which duplicates need to be removed.
    
    Returns:
    str: The modified string with duplicates removed.
    """
    result = ''  # Initialize an empty string to store the result
    seen = ''  # Initialize an empty string to track seen characters
    
    # Loop through each character in the input string
    for char in s:
        # Check if the character has not been seen before
        if char not in seen:
            seen += char  # Add the character to seen
            result += char  # Add the character to the result string
    
    return result  # Return the modified string with duplicates removed

# Connect with me:
    
# YouTube: https://www.youtube.com/@tech.mayankagg
    
# Instagram: https://www.instagram.com/tech.mayankagg/
    
# LinkedIn: https://www.linkedin.com/in/mayank953/
