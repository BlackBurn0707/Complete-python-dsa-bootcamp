# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_consonants(s):
    new_s = ''.join(letter.lower() for letter in s if letter.isalpha())
    count = len(new_s) - new_s.count('a') - new_s.count('e') - new_s.count('i') - new_s.count('o') - new_s.count('u')
    return count

count_consonants("Hello, World!")
# Out:
# helloworld
# 7

# %%
def count_consonants(s):
    """
    Function to count the number of consonants in the input string without using built-in functions.
    
    Parameters:
    s (str): The input string to check for consonants.
    
    Returns:
    int: The count of consonants in the input string.
    """
    vowels = 'aeiouAEIOU'  # Define the set of vowels (both uppercase and lowercase)
    count = 0  # Initialize a counter for consonants
    
    # Loop through each character in the string
    for char in s:
        # Check if the character is a letter (from 'a' to 'z' or 'A' to 'Z')
        if ('a' <= char <= 'z') or ('A' <= char <= 'Z'):
            # Check if the character is not a vowel
            if char not in vowels:
                count += 1  # Increment the count if it is a consonant
    
    # Return the total count of consonants
    return count

# Connect with me:
    
# YouTube: https://www.youtube.com/@tech.mayankagg
    
# Instagram: https://www.instagram.com/tech.mayankagg/
    
# LinkedIn: https://www.linkedin.com/in/mayank953/
