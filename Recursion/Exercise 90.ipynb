# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_to_n(n):
    if n <= 0:
        return ('Please enter a valid number.')
    else:
        count_to_n(n-1)
        print(n)


count_to_n(7)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
