# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def count_digits(n):
    if n >= 0 and n <= 9:
        return 1
    else:
        return (1 + count_digits(n//10))

count_digits(5)
# Out:
# 1
