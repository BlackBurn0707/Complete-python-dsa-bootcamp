# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def factorial(n):
    if n >= 2:
        return n * factorial(n-1)
    elif n >= 0:
        return 1
    else:
        return(f"Factorial of {n} cannot be calculated.")
    

factorial(9)
# Out:
# 362880
