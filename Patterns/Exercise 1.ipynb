# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def generate_square(n):
    if type(n) != int:
        print("Invalid Input!")
    elif n<=0:
        print(f"Cannot output a square list with {n} elements!")
    else:
       lst = []
       for i in range(n):
        lst.append('*' * n)
       print(lst)
generate_square(0)
# Out:
# Cannot output a list with 0 elements!

# %%
def generate_square(n):
    """
    Function to return a square pattern of '*' of side n as a list of strings.
    
    Parameters:
    n (int): The size of the square.
    
    Returns:
    list: A list of strings where each string represents a row of the square.
    """
    # Initialize an empty list to store the rows of the square
    square = []
    
    # Loop n times to generate each row
    for i in range(n):
        # Create a row of '*' of length n and append it to the list
        square.append('*' * n)
    
    # Return the list of rows
    return square
# Connect with me:
# YouTube: https://www.youtube.com/@tech.mayankagg
# Instagram: https://www.instagram.com/tech.mayankagg/
# LinkedIn: https://www.linkedin.com/in/mayank953/

generate_square(-1)
# Out:
# []
