# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def bubble_sort(arr):
    for i in range(1, len(arr), 1):
        for i in range(0, len(arr)-1, 1):
            if arr[i] > arr[i+1]:
                arr[i], arr[i+1] = arr[i+1], arr[i]
    return arr

bubble_sort([1, 45, 6, 78, 34, 4, 67, 12, 2])
# Out:
# [1, 2, 4, 6, 12, 34, 45, 67, 78]
